# %% [markdown]
# # 🐍 Aula 03 - Estruturas de repetição e controle de fluxo
#
# Até o momento, nossos códigos eram executados linha por linha, de forma estritamente sequencial. Hoje, aprenderemos a fazer o computador repetir tarefas automaticamente, processar conjuntos de dados e controlar o fluxo dessa execução de maneira cirúrgica.
#
#
# ### Objetivos da Aula
# 1. **Estruturas de Repetição**: Entender os conceitos de loops (`for` e `while`).
# 2. **Repetição com `for`**: Dominar a iteração sobre sequências e a utilização das funções `range()` e `enumerate()` dentro de funções.
# 3. **Repetição com `while`**: Compreender como repetir instruções baseadas em condições lógicas variáveis.
# 4. **Controle de Fluxo com `break` e `continue`**: Aprender a interromper ou pular iterações de loops de forma inteligente.
# 5. **Exemplos Combinados**: Analisar mini-algoritmos práticos de filtragem e análise de dados acústicos.
# 6. **Exercícios de Fixação**: Praticar com exercícios de aquecimento simples e missões aplicadas.

# %% [markdown]
# ## Introdução às Estruturas de Repetição (Loops)
#
# Na programação, as **estruturas de repetição** (também chamadas de *laços* ou *loops*) permitem que um bloco de código seja executado repetidas vezes até que uma condição específica de parada seja alcançada ou enquanto percorremos uma sequência.
#
# Imagine a necessidade de processar 1.000 leituras de um hidrofone de sonar. Escrever a linha de código 1.000 vezes seria impraticável. Com estruturas de repetição, escrevemos a instrução apenas uma vez e instruímos o computador a executá-la para cada leitura.
#
# No Python, temos dois tipos principais de loops:
#
# *   **Loop `for`**: Ideal para iterar sobre coleções ou quando sabemos previamente a quantidade de vezes que o código deve ser repetido (ou quando queremos passar por todos os itens de uma sequência, como uma string ou um intervalo de números).
# *   **Loop `while`**: Ideal para quando não sabemos exatamente quantas vezes a repetição vai acontecer, pois ela continua rodando **enquanto** uma condição lógica for verdadeira. A condição deve se tornar falsa em algum momento para evitar o temido 'loop infinito'.

# %% [markdown]
# ## Exemplos com Funções e Estrutura de Repetição `for`
#
# O loop `for` em Python é extremamente poderoso porque ele itera diretamente sobre os elementos de uma sequência (como caracteres de um texto ou números em uma sequência).
#
# ### A Função `range()`
# Uma ferramenta comum usada com o `for` é a função integrada `range()`. Ela gera uma sequência de números inteiros ajustável:
# *   `range(parada)`: Gera números de 0 até o valor anterior à `parada`.
# *   `range(inicio, parada)`: Começa no `inicio` e vai até antes da `parada`.
# *   `range(inicio, parada, passo)`: Incrementa os números de acordo com o `passo`.
#
# Vejamos exemplos práticos de sua aplicação dentro de funções:

# %% [markdown]
# #### Exemplo 1: Contagem incremental
#
# Crie uma função para contar até $N$.

# %%
# [Resposta]
#def contagem_ate(fim):
#    for i in range(1, fim + 1):
#        print(i)

N = 10 # fim
contagem_ate(N)

# %% [markdown]
# #### Exemplo 2: Contagem de n até N com passo de k
#
# Crie uma função para contar de $n$ até $N$, onde $N$ é sempre maior que $n$, com um passo de $k$.

# %%
# [Resposta]
#def contagem_de_n_ate_N(inicio, fim, passo):
#    for i in range(inicio, fim, passo):
#        print(i)

n = 0 # inicio
N = 10 # fim
k = 1 # passo
contagem_de_n_ate_N(n, N, k)

# %% [markdown]
# #### Exemplo 3: Contagem decremental.
#
# Crie uma função que inicie uma contagem regressiva de $N$ até $0$ e imprima na tela o valor atual da contagem.

# %%
# [Resposta]
#def contagem_regressiva(segundos):
#    for i in range(segundos, -1, -1):
#        print(i)

contagem_regressiva(10)

# %% [markdown]
# #### Exemplo 4: Percorrer uma string.
#
# Crie uma função que recebe uma palavra e imprima na tela cada caracter separadamente.

# %%
# [Resposta]
#def imprimir_caracteres(texto):
#    for char in texto:
#        print(char)

frase = "Este é um bom exemplo."
imprimir_caracteres(frase)

# %% [markdown]
# ### Iterando com Índices usando a Função `enumerate()`
#
# Muitas vezes, além de processar o valor de um caractere em uma string de texto em um loop `for`, precisamos saber a sua **posição** (o índice).
#
# A função integrada `enumerate()` nos ajuda exatamente nisso. Ela retorna, a cada iteração do loop, um par contendo o índice (por padrão começando em 0) e a letra correspondente.
#
# **Sintaxe Básica:**
# ```python
# for indice, letra in enumerate(texto):
#     # bloco de código utilizando o índice e o caractere
# ```

# %% [markdown]
# #### Exemplo 5: Varredura dos caracteres de uma frase
#
# Crie uma função que receba como parâmetro uma palavra como entrada.
# Você deve imprimir a posição e a letra de cada caracter contido na palavra fornecida usando a função `enumerate()`.

# %%
# [Resposta]
#def imprimir_indices_e_caracteres(palavra):
#    for idx, char in enumerate(palavra):
#        print(f"Índice {idx}: {char}")

imprimir_indices_e_caracteres("ALARME")

# %% [markdown]
# ## Exemplos com Funções e Estrutura de Repetição `while`
#
# O loop `while` testa a condição antes de executar o bloco interno. Se for verdadeira, executa. Ao final do bloco, testa novamente.
#
# **Atenção**: É fundamental que a variável testada na condição seja atualizada dentro do bloco de código do loop, caso contrário o programa ficará preso executando para sempre.

# %% [markdown]
# ### Exemplo 6:
#
# O logaritmo neperiano de um número $x > 0$ pode ser calculado utilizando o seguinte produtório:
#
# $$ln(x) = (x-1)\prod_{k=1}^{\infty}\left[\frac{2}{1+x^{1/(2^k)}}\right]$$
#
# Faça uma função em Python que recebe um número $x$, maior que $0$, e um número $k$, inteiro e maior ou igual a um, por argumento e calcula o valor aproximado de $ln (x)$  utilizando $k$ termos do produtório acima. A função deve retornar o resultado do cálculo. Você deve usar o `while`.

# %%
# [Resposta]
#def ln(x, terms):
#    prod = 1.0
#    k = 1
#    while k <= terms:
#        prod *= 2 / (1 + x ** (1 / (2 ** k)))
#        k += 1
#    return (x - 1) * prod

x = 10
print(f"ln({x}) = {ln(x, 100)}")

# %% [markdown]
# ### Exemplo 7: Testar se um número $n$ é primo.
#
# Neste exercício, você vai criar duas funções em Python para trabalhar com divisores e números primos.
#
# Antes de começar o código, vale relembrar dois conceitos fundamentais para a solução:
#
# * O resto da divisão exata em Python é calculado usando o operador de módulo, representado pelo símbolo de porcentagem. Dizemos que um número é divisor de outro quando a divisão entre eles é exata, ou seja, quando o resto é igual a zero. Por exemplo, a expressão `10 % 2` resulta em $0$, o que confirma que $2$ é um divisor de $10$. Por outro lado, `10 % 3` resulta em $1$, mostrando que $3$ não é um divisor de $10$.
# * A definição de um número primo diz que ele é um número inteiro e positivo que possui exatamente dois divisores: o número $1$ e ele mesmo. Como exemplo, o número $7$ é primo porque é divisível apenas por $1$ e por $7$. Já o número $6$ não é primo, pois possui quatro divisores, que são os números $1$, $2$, $3$ e $6$.
#
# Com base nisso, resolva as duas etapas abaixo:
#
# * Crie a primeira função chamada `contar_divisores`. Ela deve receber um número inteiro e positivo como argumento e utilizar um loop `while` para testar todos os números de `1` até o valor recebido `n`. A função deve retornar a quantidade total de divisores exatos encontrados.
# * Crie a segunda função chamada `is_primo`. Ela deve receber o mesmo número como argumento, chamar a função `contar_divisores` e retornar `True` se o número for primo ou `False` caso contrário.

# %%
# [Resposta]
#def contar_divisores(n):
#    count = 0
#    i = 1
#    while i <= n:
#        if n % i == 0:
#            count += 1
#        i += 1
#    return count

#def is_primo(n):
#    return contar_divisores(n) == 2

print("7 é primo?", is_primo(7))
print("6 é primo?", is_primo(6))

# %% [markdown]
# ## Controles de Fluxo `break` e `continue`
#
# Em cenários reais, precisamos ter flexibilidade sobre a execução de um loop. O Python nos fornece duas ferramentas cruciais de controle:
#
# ### O Comando `break`
# O `break` interrompe a execução do loop imediatamente e salta para a primeira linha de código fora do bloco de repetição. É frequentemente usado quando encontramos o que estávamos procurando e não há necessidade de continuar a busca.
#
# ### O Comando `continue`
# O `continue` encerra apenas a iteração atual do loop. O interpretador ignora as linhas de código restantes abaixo do `continue` e salta diretamente para o teste de condição da próxima iteração. É ideal para ignorar elementos indesejados ou ruídos durante um processamento.

# %%
# Visualizando o funcionamento do break
print("--- Exemplo do Break ---")
for numero in range(1, 6):
    if numero == 4:
        print(f"Encontrado {numero}. Parando o loop!")
        break
    print(f"Número: {numero}")
    
print("fim!")

# %%
# Visualizando o funcionamento do continue
print("\n--- Exemplo do Continue ---")
for numero in range(1, 6):
    if numero == 4:
        print(f"Ignorando o número {numero}.")
        continue
    print(f"Número: {numero}")

print("fim!")

# %% [markdown]
# ## Exemplos Práticos Combinados de Repetição e Controle de Fluxo

# %% [markdown]
# ### Exemplo 8:
#
# O sensor de sonar do submarino está registrando as amplitudes dos ecos acústicos gerados por uma sequência matemática para os próximos `total_pings`. No entanto, devido à reverberação das ondas, alguns pings representam ruído nulo ou negativo e devem ser pulados (`continue`). Apenas pings positivos saudáveis devem ser acumulados à energia líquida total.
#
# **Instruções do Exercício**:
# Crie uma função chamada `processar_energia_pings(total_pings)`:
# 1.  Inicialize a variável `energia_total` em 0.0.
# 2.  Utilize um loop `for` e `range()` de 1 até `total_pings` (inclusive).
# 3.  Calcule a amplitude simulada do ping atual `i` usando a fórmula:
#     $$\text{amplitude} = (i \times 3) - 10$$
# 4.  Se a `amplitude` for menor ou igual a 0.0, imprima: `'Ping #[i] ignorado (ruído).'` e salte para a próxima iteração imediatamente usando o comando `continue`.
# 5.  Caso contrário, adicione a `amplitude` ao acumulador `energia_total` e exiba a mensagem: `'Ping #[i] processado com amplitude de [amplitude] dB.'`.
# 6.  Ao final do processamento, a função deve retornar o valor acumulado da `energia_total` arredondado para duas casas decimais com a função `round()`.

# %%
# [Resposta]
#def processar_energia_pings(total_pings):
#    energia_total = 0.0
#    for i in range(1, total_pings + 1):
#        amplitude = (i * 3) - 10
#        if amplitude <= 0.0:
#            print(f"Ping #{i} ignorado (ruído).")
#            continue
#        energia_total += amplitude
#        print(f"Ping #{i} processado com amplitude de {amplitude} dB.")
#    return round(energia_total, 2)

print("Energia total líquida:", processar_energia_pings(10))

# %% [markdown]
# ### Exemplo 9: Testar números ímpares.
#
# Crie uma função que dado um intervalo de números inteiros $n_1$ e $n_2$, você deve retornar a soma de todos os números ímpares dentro desse intervalo. Além disso, a função deve implementar os seguintes tratamentos:
# * Se $n_1$ ou $n_2$ não forem inteiros, retorne uma mensagem de erro.
# * Se $n_1 > n_2$, você deve inverter os valores antes de iniciar a contagem.

# %%
# [Resposta]
#def somar_impares(n1, n2):
#    if not isinstance(n1, int) or not isinstance(n2, int):
#        return "Erro: Parâmetros devem ser inteiros."
#    if n1 > n2:
#        n1, n2 = n2, n1
#    soma = 0
#    for num in range(n1, n2 + 1):
#        if num % 2 != 0:
#            soma += num
#        # é par se n%2 = 0
#    return soma

print("Soma dos ímpares de 1 a 10:", somar_impares(1, 10))

# %% [markdown]
# ### Exemplo 10:
#
# Crie a função `imprimir_tabuada(n)`. Ela deve receber como argumento o número máximo $n$ e imprimir a tabuada completa de todos os números de $1$ até $n$. Para isso, utilize dois laços `for` aninhados: o laço externo vai de $1$ até $n$, e o interno vai de $1$ a $10$ para exibir as multiplicações de cada número.

# %%
# [Resposta]
#def contagem_ate(fim):
#    for i in range(1, fim + 1):
#        print(i)

N = 10 # fim
contagem_ate(N)

# %% [markdown]
# ### Lista de Exercícios.
#
# Faça a Lista de Exercícios 3.

# %% [markdown]
# ### Exemplo 11: O Desafio do Cavaleiro e a Torre Infinitamente Perigosa
#
# O jovem cavaleiro encontrou a lendária *Torre Mágica dos Mil Baús*. Dizem os bardos que a torre possui infinitos andares e que em cada um deles existe um único baú. No entanto, explorar a torre é extremamente arriscado:
#
# * Alguns baús contêm sacos cheios de **moedas de ouro**.
# * Outros baús estão completamente **vazios**.
# * E em alguns baús esconde-se a terrível **Armadilha do Dragão**!
#
# Sem saber quantas salas conseguirá explorar antes de encontrar o perigo fatal, o cavaleiro precisa subir andar por andar acumulando o máximo de ouro que puder, sabendo a hora exata de fugir! Sua missão é programar o algoritmo de navegação do cavaleiro utilizando **Python**. O programa deve simular a subida da torre andar por andar até que o cavaleiro encontre o dragão e fuja da torre.
#
# Crie uma função sem parâmetros chamada `abrir_bau()` que sorteia o evento do baú utilizando o módulo `random`.
#
# Primeiro, sorteie um número de $1$ a $100$ para definir a chance do evento:
# * **50% de chance (números de 1 a 50):** O baú está **vazio**. A função deve retornar o valor `0`.
# * **10% de chance (números de 51 a 60):** O baú é uma **armadilha de dragão**. A função deve retornar um código de perigo negativo (sorteie um número de `-10` a `-1`).
# * **40% de chance (números de 61 a 100):** O baú tem **moedas de ouro**. Nesse caso, faça um segundo sorteio de `1` a `50` para definir a quantidade exata de moedas encontradas e **retorne esse valor positivo**.
#
#
# Por fim, crie a função `subir_torre()`. No fluxo principal do programa, simule a subida dos andares usando um laço contínuo `while True` (loop infinito):
#
# 1. A cada iteração do laço, **incremente a contagem do andar** em $+1$ e exiba qual andar o cavaleiro está explorando.
# 2. Chame a função `abrir_bau()` e armazene o resultado em uma variável.
# 3. **Se o resultado for `0` (Baú Vazio):**
#    * Exiba uma mensagem dizendo que o baú está vazio.
#    * Use o comando **`continue`** para pular o restante do código e ir direto para o próximo andar (sem somar nada).
# 4. **Se o resultado for Menor que `0` (Dragão):**
#    * Exiba uma mensagem de alerta com o código do perigo.
#    * Use o comando **`break`** para encerrar o laço imediatamente, pois o cavaleiro precisa fugir para sobreviver!
# 5. **Se o resultado for Maior que `0` (Moedas):**
#    * Somar a quantidade de moedas ao total acumulado.
#    * Exibir quantas moedas foram encontradas e o total acumulado até o momento.
#
#
# Fora do laço `while`, exiba o resumo final da aventura com o **último andar alcançado** e a **quantidade total de moedas de ouro** que o cavaleiro conseguiu levar para casa.
#
#
#
#
# **Dica:** A função `randint(a, b)`, do módulo `random`, é uma das mais utilizadas do módulo `random`. Ela serve para **gerar um número inteiro aleatório** dentro de um intervalo fechado, ou seja, incluindo tanto o limite inferior `a` quanto o limite superior `b`. É fundamental entender que o `randint()` trabalha com uma **distribuição uniforme** onde todos os números dentro do intervalo têm **exatamente a mesma chance** de serem sorteados. Se você sorteia um número entre `1` e `10`, a chance de sair o número `1` é de exatamente 10% ($\frac{1}{10}$), a mesma chance de sair o número `7` ou `10`.
#
# ```python
# import random
# numero_sorteado = random.randint(inicio, fim)
# ```

# %%
# [Resposta]

# %% [markdown]
# ### Exemplo 12: Iteração Avançada com `enumerate()`, `break` e `continue`
#
# O operador do rádio do submarino interceptou uma cadeia de sinais codificados como uma string de texto. Cada caractere representa uma leitura acústica específica:
# *   `'S'` (Safe): Sinal seguro (deve ser processado).
# *   `'R'` (Ruído): Ruído de fundo (deve ser ignorado usando `continue`).
# *   `'H'` (Hostile): Sinal de ameaça hostil detectado (o escaneamento deve ser imediatamente abortado por segurança usando `break`).
#
# #### Pseudocódigo:
# ```text
# Função escanear_transmissao_cripto(mensagem_codificada):
#     Escrever mensagem de início de escaneamento
#
#     Para cada (posicao, caractere) obtidos ao enumerar a mensagem_codificada:
#         Se caractere for igual a 'R':
#             Escrever mensagem de ruído ignorado
#             Pular para a próxima iteração (continue)
#
#         Se caractere for igual a 'H':
#             Escrever alerta de ameaça detectada
#             Interromper o laço de repetição (break)
#
#         Escrever mensagem de sinal processado com sucesso
#
#     Escrever mensagem de conclusão do processamento
# ```

# %%
# [Resposta]
