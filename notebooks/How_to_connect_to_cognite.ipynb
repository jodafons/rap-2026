# %% [markdown]
# # How to Donwload Cognite Database?

# %%
# %config InlineBackend.figure_format = 'retina'
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import atlas_mpl_style as ampl
import os, warnings
import matplotlib

from loguru import logger
from itm.clients import Cognite
from datetime import datetime

ampl.use_atlas_style()
plt.rcParams['font.family'] = 'DeJavu Sans'
plt.rcParams['font.serif'] = ['Times New Roman']
warnings.filterwarnings("ignore")
matplotlib.use('Agg')

# %% [markdown]
# ## How to connect?

# %%
CLIENT_SECRET = "olz8Q~.m0ldyXULnMnry_NiWhb~2FDmgWYzeBcKZ" # this came from CDF token generation page
TENANT_ID     = "48d5043c-cf70-4c49-881c-c638f5796997" # this is the dataset project id
client        = Cognite("compressor", client_secret=CLIENT_SECRET, tenant_id=TENANT_ID)
# Out:
# 2026-03-28 20:15:50.096 | INFO     | itm.clients.cognite:__init__:72 - publicdata

# %%
start_time = datetime(2019, 9, 1) # Tempo disponível no dataset (6 meses)
end_time = datetime(2020, 3, 1)
df, info = client.get_dataframe( '23-KA-9101', start_time, end_time )
# Out:
# 2026-03-28 20:18:59.217 | INFO     | itm.clients.cognite:get_dataframe:178 - Searching data from 2019-09-01 00:00:00 to 2020-03-01 00:00:00 for asset '23-KA-9101'
# {'VAL_23-KA-9101_APE:VALUE': 'PH (CBM) 1st Stage ActCompr Poly Eff',
#  'VAL_23-KA-9101_APH:VALUE': 'PH (CBM) 1st Stg ActCompr Poly Head',
#  'VAL_23-KA-9101_APR:VALUE': 'PH (CBM) 1st Stage ActPress Ratio',
#  'VAL_23-KA-9101_ASP:VALUE': 'PH (CBM) 1st Stage ActShaft Power',
#  'VAL_23-KA-9101_EPE:VALUE': 'PH (CBM) 1st Stage ExpCompr Poly Eff',
#  'VAL_23-KA-9101_EPH:VALUE': 'PH (CBM) 1st Stg ExpCompr Poly Head',
#  'VAL_23-KA-9101_EPR:VALUE': 'PH (CBM) 1st Stage ExpPress Ratio',
#  'VAL_23-KA-9101_ESP:VALUE': 'PH (CBM) 1st Stage ExpShaft Power',
#  'VAL_23-KA-9101_PED:VALUE': 'PH (CBM) 1st Stage Poly Eff Dev',
#  'VAL_23-KA-9101_PHD:VALUE': 'PH (CBM) 1st Stage Poly Head Dev',
#  'VAL_23-KA-9101_PRD:VALUE': 'PH (CBM) 1st Stage Press Rat Dev',
#  'VAL_23-KA-9101_SPD:VALUE': 'PH (CBM) 1st Stage Shft Pwr Dev'}
# MultiIndex([('VAL_23-KA-9101_EPR:VALUE', 'average'),
#             ('VAL_23-KA-9101_PHD:VALUE', 'average'),
#             ('VAL_23-KA-9101_ASP:VALUE', 'average'),
#             ('VAL_23-KA-9101_PRD:VALUE', 'average'),
#             ('VAL_23-KA-9101_APH:VALUE', 'average'),
#             ('VAL_23-KA-9101_PED:VALUE', 'average'),
#             ('VAL_23-KA-9101_SPD:VALUE', 'average'),
# 2020-03-01 02:58:52                            80.696562
# 2020-03-01 02:59:22                            80.808337
# 2020-03-01 02:59:52                            80.828725
#
# identifier          PH (CBM) 1st Stage ExpShaft Power  \
# aggregate                                     average
# 2020-03-01 02:57:52                       8308.720221
# 2020-03-01 02:58:22                       8898.043657
# 2020-03-01 02:58:52                       9160.199229
# 2020-03-01 02:59:22                       8842.232082
# 2020-03-01 02:59:52                       8545.773223
#
# identifier          PH (CBM) 1st Stage ActPress Ratio  \
# aggregate                                     average
# 2020-03-01 02:57:52                          3.590546
# 2020-03-01 02:58:22                          3.543732
# 2020-03-01 02:58:52                          3.476781
# 2020-03-01 02:59:22                          3.511954
# 2020-03-01 02:59:52                          3.580271
#
# identifier          PH (CBM) 1st Stg ExpCompr Poly Head
# aggregate                                       average
# 2020-03-01 02:57:52                          134.812568
# 2020-03-01 02:58:22                          130.649197
# 2020-03-01 02:58:52                          145.619097
# 2020-03-01 02:59:22                          151.481747
# 2020-03-01 02:59:52                          149.980894

# %%
info.head()
# Out:
#                  id            created_time       last_updated_time  is_step  \
# 0   460210694425061 2020-06-24 18:51:54.298 2026-03-23 13:05:25.440    False
# 1  1669469338541465 2020-06-24 18:51:54.298 2026-03-23 13:05:26.777    False
# 2  3386754896121434 2020-06-24 18:51:54.298 2026-03-23 13:05:23.392    False
# 3  3702305190557142 2020-06-24 18:51:54.298 2026-03-23 13:05:27.363    False
# 4  4012168589282214 2020-06-24 18:51:54.298 2026-03-23 13:05:22.326    False
#
#    is_string               external_id                      name  \
# 0      False  VAL_23-KA-9101_EPR:VALUE  VAL_23-KA-9101_EPR:VALUE
# 1      False  VAL_23-KA-9101_PHD:VALUE  VAL_23-KA-9101_PHD:VALUE
# 2      False  VAL_23-KA-9101_ASP:VALUE  VAL_23-KA-9101_ASP:VALUE
# 3      False  VAL_23-KA-9101_PRD:VALUE  VAL_23-KA-9101_PRD:VALUE
# 4      False  VAL_23-KA-9101_APH:VALUE  VAL_23-KA-9101_APH:VALUE
#
#                                             metadata          asset_id  \
# 0  {'compdev': '0', 'location5': '2', 'pointtype'...  3047932288982463
# 1  {'compdev': '0', 'location5': '2', 'pointtype'...  3047932288982463
# 2  {'compdev': '0', 'location5': '2', 'pointtype'...  3047932288982463
# 3  {'compdev': '0', 'location5': '2', 'pointtype'...  3047932288982463
# 4  {'compdev': '0', 'location5': '2', 'pointtype'...  3047932288982463
#
#                            description security_categories unit
# 0    PH (CBM) 1st Stage ExpPress Ratio                  []  NaN
# 1     PH (CBM) 1st Stage Poly Head Dev                  []  NaN
# 2    PH (CBM) 1st Stage ActShaft Power                  []   kw
# 3     PH (CBM) 1st Stage Press Rat Dev                  []    %
# 4  PH (CBM) 1st Stg ActCompr Poly Head                  []  NaN

# %%
df.shape
# Out:
# (547508, 12)

# %%
df.to_csv("compressor.csv")
